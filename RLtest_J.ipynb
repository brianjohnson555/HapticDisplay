# %% [markdown]
# Import packages

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# Load environment, define functions, set paths

# %%
# Load environment
env_name = 'CartPole-v1'
env = gym.make(env_name)
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model_cartpole')
log_path = os.path.join('Training','Logs')

def Test(episodes,env,model):
    for episode in range(1,episodes+1):
        obs = env.reset()
        done = False
        score = 0

        while not done:
            env.render()
            action, _states = model.predict(obs)
            obs, reward, done, info = env.step(action)
            score += reward
        print('Episode:{} Score:{}'.format(episode, score))
    env.close()

# %% [markdown]
# Training step

# %%
Training = True
if Training:

    # Define algorithm
    env = DummyVecEnv([lambda: env])
    model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)

    # Learning
    model.learn(total_timesteps=20000)

    # Save model
    model.save(PPO_path)
# Out:
# Using cpu device
# Logging to Training\Logs\PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 3762 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2142        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008984506 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00203     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.55        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 49.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1891        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010717582 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.0954      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 36.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1810        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010248747 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.626      |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1762        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008156801 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 56          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1715        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006888331 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 61.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010502234 |
# |    clip_fraction        | 0.0714      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 58          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1673         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0055077765 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.56        |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.71         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 39.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1658        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008743185 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.76        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 39.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1625         |
# |    iterations           | 10           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0044991355 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.9          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00732     |
# |    value_loss           | 25.9         |
# ------------------------------------------

# %% [markdown]
# Load model and run test

# %%
# Load model
model = PPO.load(PPO_path, env=env)
# evaluate_policy(model, env, n_eval_episodes=10, render=True)
Test(5, env, model)

training_log_path = os.path.join(log_path,'PPO_2')
# tensorboard --logdir={training_log_path}
# Out:
# Episode:1 Score:[478.]
# Episode:2 Score:[500.]
# Episode:3 Score:[500.]
# Episode:4 Score:[433.]
# Episode:5 Score:[472.]
